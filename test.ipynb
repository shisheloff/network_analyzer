# %%
import pandas as pd, matplotlib as plt, networkx as nx
network_data = pd.read_csv("C:\\Users\\shish\\DataspellProjects\\network_analyzer\\test.csv")

network = nx.from_pandas_edgelist(network_data, source='Source', target='Destination', edge_attr=True)
network.nodes()
network.edges()
nx.draw_circular(network, with_labels=True)
